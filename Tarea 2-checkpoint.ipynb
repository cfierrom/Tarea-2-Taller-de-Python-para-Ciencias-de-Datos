# %% [markdown]
# Tarea 2
#
# Para comenzar debemos importar las librerias para leer y manipular los datos del archivo .csv, para ello vamos a escrbir "import pandas as pd" e "import numpy as np"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# El archivo que vamos a manipular es de un estudio de especies y el peso de los animales capturados en sitios dentro de nuestra área de estudio. El conjunto de datos esta guardado en un archivo .csv: cada línea tiene información sobre un solo animal y las columnas representan:
#
#
# El archivo que vamos a manipular es de un estudio de dos tipos de vinos, el vino blanco y el vino rojo, los cuales extrajimos de la UC Irvine Machine Learning Repository (https://archive.ics.uci.edu/ml/datasets/wine+quality):
#
# Las entradas incluyen pruebas objetivas (por ejemplo, valores de PH) y la salida se basa en datos sensoriales
# (mediana de al menos 3 valoraciones realizadas por enólogos). Cada experto calificó la calidad del vino
# entre 0 (muy malo) y 10 (muy excelente).
#
# Columna Descripción
#
# - fixed acidity: Acidez fija
# - volatile acidity: Acidez volatil
# - citric acid: Ácido citrico
# - residual sugar: Azúcar residual
# - chlorides: Cloruros
# - free sulfur dioxide: Dióxido de azufre libre
# - total sulfur dioxide: Dióxido de azufre total
# - density: Densidad [$\frac{g}{mL}$]
# - pH: pH medida de acidez
# - sulphates: Sulfatos
# - alcohol: Alcohol en grados
# - quality: Calidad de 0 a 10
# - Type-Wine: Tipo de vino (blanco y rojo)

# %% [markdown]
# 1. Utilizar los métodos pandas.read_xxx() y pandas.to_xxx() para leer y guardar los
# datos
# 2. Revisar si los datos de entrada tienen o no un encabezado. De no ser así, corregir esta
# situación

# %%
df = pd.read_csv('winequality2.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# 3- Realizar un análisis básico de los datos de entrada con con los métodos .describe() y
# .info()

# %%
df.info()
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6472 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6350 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6457 non-null   float64
#  11  quality               6497 non-null   int64
#  12  Type-Wine             6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB
# ...

# %% [markdown]
# - La calidad del vino varía de 3 a 8, donde 6 es la calidad media.
# - El nivel máximo de alcohol en el vino es 14.9 y el mínimo es 8.4
# - El nivel de pH del vino varía entre 2,72 y 4,01.
# - La densidad media del vino es 0,9956.
# - El total de dióxido de azufre total varía entre 6,0 y 440.

# %% [markdown]
# 4. Identificar y manipular valores faltantes
#     - $a.$ Identificar valores faltantes
#     - $b.$ Manipular valores faltantes
#     - $c.$ Correguir el formato de los datos

# %%
print("Existen ",df.isnull().sum().sum(), "valores faltantes")
# Out:
# Existen  212 valores faltantes

# %%
datos_faltantes = df.isnull()
datos_faltantes.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          False             False        False           False      False
# 1          False             False        False           False      False
# 2          False             False        False           False      False
# 3          False             False        False           False      False
# 4          False             False        False           False      False
# 5          False             False        False           False      False
# 6          False             False        False           False      False
# 7          False             False        False           False      False
# 8          False             False        False           False      False
# 9          False             False        False           False      False
#
#    free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid               0
# residual sugar           25
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                 147
# pH                        0
# sulphates                 0
# alcohol                  40
# quality                   0
# Type-Wine                 0
# dtype: int64

# %% [markdown]
# Basado en el resumen anterior, cada columna tiene $4898$ filas de datos y $12$ columnas. En $2$ columnas podemos observar datos faltantes.
#
# 1. En la columna residual sugar, $25$ datos faltantes.
# 2. En la columna density, $147$ datos faltantes.
# 3. En la columna alcohol, $40$ datos faltantes.
#
#
# Separamos los Dataframe por tipo de vino, para obtener los promedios de los datos faltantes y remplazar estos datos. Luego volveremos a concatenar estos DF

# %%
df_white = df[df['Type-Wine']=='White']
df_red = df[df['Type-Wine']=='Red']

# %%
df_white.isnull().sum(axis = 0)
# Out:
# fixed acidity            0
# volatile acidity         0
# citric acid              0
# residual sugar          25
# chlorides                0
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                 76
# pH                       0
# sulphates                0
# alcohol                 34
# quality                  0
# Type-Wine                0
# dtype: int64

# %%
df_red.isnull().sum(axis = 0)
# Out:
# fixed acidity            0
# volatile acidity         0
# citric acid              0
# residual sugar           0
# chlorides                0
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                 71
# pH                       0
# sulphates                0
# alcohol                  6
# quality                  0
# Type-Wine                0
# dtype: int64

# %%
prom_sug = df_white["residual sugar"].astype("float").mean(axis=0)
prom_density = df_white["density"].astype("float").mean(axis=0)
prom_alcohol = df_white["alcohol"].astype("float").mean(axis=0)

print("Promedio de azucar residual:", prom_sug)
print("Promedio de la densidad:", prom_density)
print("Promedio del alcohol:", prom_alcohol)

df_white["residual sugar"].replace(np.nan, prom_sug, inplace=True)
df_white["density"].replace(np.nan, prom_density, inplace=True)
df_white["alcohol"].replace(np.nan, prom_alcohol, inplace=True)
# Out:
# Promedio de azucar residual: 6.349076544223286
# Promedio de la densidad: 0.993911184155946
# Promedio del alcohol: 10.510929276315828
# C:\Users\56981\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
prom_sug = df_red["residual sugar"].astype("float").mean(axis=0)
prom_density = df_red["density"].astype("float").mean(axis=0)
prom_alcohol = df_red["alcohol"].astype("float").mean(axis=0)

print("Promedio de azucar residual:", prom_sug)
print("Promedio de la densidad:", prom_density)
print("Promedio del alcohol:", prom_alcohol)

df_red["residual sugar"].replace(np.nan, prom_sug, inplace=True)
df_red["density"].replace(np.nan, prom_density, inplace=True)
df_red["alcohol"].replace(np.nan, prom_alcohol, inplace=True)
# Out:
# Promedio de azucar residual: 2.5388055034396517
# Promedio de la densidad: 0.9965468390052351
# Promedio del alcohol: 10.422379158819808

# %%
df=pd.concat([df_red, df_white]).reset_index(drop=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# 5. Estandarizar datos de entrada.

# %% [markdown]
# Para estandarizar, vamo a elegir la variable densidad que se encuentra con las medidas [$\frac{g}{mL}$], por lo tanto, lo estandarizaremos a las medidas del Sistema Internacional, es decir, a [$\frac{kg}{m^3}$]. Para ello multiplicaremos toda la columna por $1.000$

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Type-Wine
# 0      9.4        5       Red
# ...

# %%
df['density-kg/m^3'] = df["density"]*1000
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Type-Wine  density-kg/m^3
# ...

# %% [markdown]
# Luego de que ya tenemos estandarizada la columna ```density```, la borramos dejando  ```density-kg/m^3``` usando la función ```pop```

# %%
df.pop('density')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 11.0                  34.0  3.51       0.56      9.4
# 1                 25.0                  67.0  3.20       0.68      9.8
# 2                 15.0                  54.0  3.26       0.65      9.8
# 3                 17.0                  60.0  3.16       0.58      9.8
# 4                 11.0                  34.0  3.51       0.56      9.4
#
#    quality Type-Wine  density-kg/m^3
# 0        5       Red           997.8
# ...

# %% [markdown]
# 6. Normalizar datos de entrada
#
# Se utilizara la normalizacion de min-max
#
# $valor  nuevo = \frac{x_i – mínimo(x)}{máximo(x) – mínimo(x)}$

# %%
df['total sulfur dioxide'] =  (df['total sulfur dioxide']- df['total sulfur dioxide'].min())/ (df['total sulfur dioxide'].max()- df['total sulfur dioxide'].min())

df['total sulfur dioxide']
# Out:
# 0       0.064516
# 1       0.140553
# 2       0.110599
# 3       0.124424
# 4       0.064516
#           ...
# 6492    0.198157
# 6493    0.373272
# 6494    0.241935
# 6495    0.239631
# 6496    0.211982
# Name: total sulfur dioxide, Length: 6497, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,10))
ax = sns.distplot(df['alcohol'])
ax.set_title('Distribución de la concentración de alcohol', size=20)
ax.set(ylabel='Densidad', xlabel='Alcohol')
# Out:
# C:\Users\56981\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Densidad'), Text(0.5, 0, 'Alcohol')]

# %% [markdown]
# Podemos ver en este grafico que la mayor concentración de alcohol se encuentra entre los 9 y 12 grados

# %% [markdown]
# 7. Agrupar datos de entrada.

# %%
import matplotlib.pyplot as plt
#from matplotlib import pyplot

plt.hist(df["quality"])

# setear las etiquetas para los ejes x e y más un título
plt.xlabel("quality")
plt.ylabel("cantidad")
plt.title("Contenedores quality")
# Out:
# Text(0.5, 1.0, 'Contenedores quality')

# %%
contenedores = np.linspace(min(df["quality"]), max(df["quality"]), 4)
contenedores
nombres_de_grupo = ['Mala', 'Media', 'Alta']
df['quality classification'] = pd.cut(df['quality'], contenedores, labels=nombres_de_grupo, include_lowest=True )
df[['quality','quality classification']].head(20)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# Grafico de barras segun calidad (`Mala`, `Media`, `Alta`) de los vinos(`vino blanco` y `vino rojo`)

# %%
plt.bar(nombres_de_grupo, df["quality classification"].value_counts())

# setear las etiquetas para los ejes x e y más un título
plt.xlabel("quality")
plt.ylabel("cantidad")
plt.title("Quality Wine")
# Out:
# Text(0.5, 1.0, 'Quality Wine')

# %% [markdown]
# Primero separamos los DF en vino blanco y vino rojo para graficar por separado, ademas se crea una funcion para agregar las cantidad correspondientes a cada barra (`mala`, `media`, `alta`), ya que sin esto es dificil aprecia los valores que estos puedan poseer.

# %%
df_white = df[df['Type-Wine']=='White']
df_red = df[df['Type-Wine']=='Red']

def agregar_valor_columna(x_list,y_list):
    for i in range(0, len(x_list)):
        plt.text(i,y_list[i-1]/2,y_list[i-1], ha="center")


plt.bar(nombres_de_grupo,df_white["quality classification"].value_counts() )
valores=[1640,180,3078]
agregar_valor_columna(nombres_de_grupo,valores)
plt.title("Quality Wine")
plt.xlabel("Quality")
plt.ylabel("Cantidad")
plt.show()

# %%
plt.bar(nombres_de_grupo,df_red["quality classification"].value_counts() )
valores=[837,18,744]
agregar_valor_columna(nombres_de_grupo,valores)
plt.title("Quality Wine")
plt.xlabel("Quality")
plt.ylabel("Cantidad")
plt.show()
df_red["quality classification"].value_counts()
# Out:
# Media    837
# Mala     744
# Alta      18
# Name: quality classification, dtype: int64

# %%
plt.bar(nombres_de_grupo, df_white["quality classification"].value_counts(), width = 0.4)
plt.bar(nombres_de_grupo, df_red["quality classification"].value_counts(), width = 0.4)
# setear las etiquetas para los ejes x e y más un título
plt.xlabel("Quality")
plt.ylabel("cantidad")
plt.title("Quality Wine")
plt.legend(('White Wine', 'Red Wine'))

# %% [markdown]
# En este gráfico podemos apreciar el contraste del vino blanco, de barras de color azul, y el vino rojo, de barras de color naranjo, donde podemos ver que hay una mayor presencia con respecto a la calidad en el vino blanco que del vino rojo al igual que en alta calidad, pero practicamente existe la misma cantidad de calidad media en ambos tipos de vino.

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# 8. Generar variables indicadoras.

# %%
dummy_1 = pd.get_dummies(df["Type-Wine"])
dummy_1.head()

df['Red']=dummy_1['Red']
df['White']=dummy_1['White']
df.drop("Type-Wine", axis = 1, inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#df3 = pd.read_csv('winequality-red2.csv')
#df2= pd.read_csv('winequality-white.csv', sep=';')
#df3['Type-Wine']= "Red"
#df2['Type-Wine']= "White"

#df4=pd.concat([df2, df3], sort=False)

#df.to_csv("winequality2.csv", index=False)
